# %%
from collections import Counter
from collections import Counter
from typing import List, Dict, Tuple, Union

# Assuming the tokenize function is defined elsewhere
def tokenize(text):
    # Tokenization logic, removing HTML and stopwords as discussed earlier
    soup = BeautifulSoup(text, "html.parser")
    cleaned_text = soup.get_text()
    tokens = cleaned_text.lower().split()
    filtered_tokens = [token for token in tokens if token not in stopwords]
    return filtered_tokens

def build_vocab(sentences, max_vocab_size=10000):
    counter = Counter()
    for text in sentences:
        counter.update(tokenize(text))

    # Take only the top max_vocab_size-1 most frequent words (leave room for special tokens)
    most_common = counter.most_common(max_vocab_size - 2)  # -2 for <pad> and <unk>

    # Create vocabulary with indices starting from 2
    vocab = {word: idx + 2 for idx, (word, _) in enumerate(most_common)}
    vocab['<pad>'] = 0  # Add padding token
    vocab['<unk>'] = 1  # Add unknown token
    return vocab

def texts_to_sequences(sentences, word_index):
    sequences = []
    for sentence in sentences:
        sequence = []
        for word in tokenize(sentence):
            # Use unknown token (1) for words not in vocabulary
            sequence.append(word_index.get(word, 1))
        sequences.append(sequence)
    return sequences

def pad_sequences(sequences, max_len):
    padded_sequences = []
    for seq in sequences:
        if len(seq) > max_len:
            padded_seq = seq[:max_len]
        else:
            padded_seq = seq + [0] * (max_len - len(seq))
        padded_sequences.append(padded_seq)
    return padded_sequences

def word_frequency(sentences, word_dict):
    frequency = {word: 0 for word in word_dict}

    for sentence in sentences:
        words = sentence.lower().split()
        for word in words:
            if word in frequency:
                frequency[word] += 1

    return frequency

# %%
# Handling Stop Words
import json


from bs4 import BeautifulSoup
import string

stopwords = ["a", "about", "above", "after", "again", "against", "all", "am", "an", "and", "any", "are", "as", "at",
             "be", "because", "been", "before", "being", "below", "between", "both", "but", "by", "could", "did", "do",
             "does", "doing", "down", "during", "each", "few", "for", "from", "further", "had", "has", "have", "having",
             "he", "hed", "hes", "her", "here", "heres", "hers", "herself", "him", "himself", "his", "how",
             "hows", "i", "id", "ill", "im", "ive", "if", "in", "into", "is", "it", "its", "itself",
             "lets", "me", "more", "most", "my", "myself", "nor", "of", "on", "once", "only", "or", "other", "ought",
             "our", "ours", "ourselves", "out", "over", "own", "same", "she", "shed", "shell", "shes", "should",
             "so", "some", "such", "than", "that", "thats", "the", "their", "theirs", "them", "themselves", "then",
             "there", "theres", "these", "they", "theyd", "theyll", "theyre", "theyve", "this", "those", "through",
             "to", "too", "under", "until", "up", "very", "was", "we", "wed", "well", "were", "weve", "were",
             "what", "whats", "when", "whens", "where", "wheres", "which", "while", "who", "whos", "whom", "why",
             "whys", "with", "would", "you", "youd", "youll", "youre", "youve", "your", "yours", "yourself",
             "yourselves"]

table = str.maketrans('', '', string.punctuation)

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/learning-datasets/sarcasm.json \
    -O /tmp/sarcasm.json


with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)


sentences = []
labels = []
urls = []
for item in datastore:
    sentence = item['headline'].lower()
    sentence = sentence.replace(",", " , ")
    sentence = sentence.replace(".", " . ")
    sentence = sentence.replace("-", " - ")
    sentence = sentence.replace("/", " / ")
    soup = BeautifulSoup(sentence)
    sentence = soup.get_text()
    words = sentence.split()
    filtered_sentence = ""
    for word in words:
        word = word.translate(table)
        if word not in stopwords:
            filtered_sentence = filtered_sentence + word + " "
    sentences.append(filtered_sentence)
    labels.append(item['is_sarcastic'])
    urls.append(item['article_link'])

xs=[]
ys=[]
current_item=1
for item in sentences:
  xs.append(current_item)
  current_item=current_item+1
  ys.append(len(item))
newys = sorted(ys)

#import matplotlib.pyplot as plt
#plt.plot(xs,newys)
#plt.axis([20000, 27000, 50, 250])
#plt.show()

#print(newys[20000])
# Out:
# --2024-10-31 18:08:39--  https://storage.googleapis.com/learning-datasets/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.12.207, 172.217.194.207, 172.253.118.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.12.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  3.98MB/s    in 1.4s
#
# 2024-10-31 18:08:41 (3.98 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]
# <ipython-input-3-f2daca70d7b3>:17: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(sentence)

# %%
vocab_size = 2000
embedding_dim = 7
max_length = 85
training_size = 23000

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# Updated for vocab size limitation
word_index = build_vocab(training_sentences, max_vocab_size=vocab_size)
training_sequences = texts_to_sequences(training_sentences, word_index)
training_padded = pad_sequences(training_sequences, max_len=max_length)


testing_sequences = texts_to_sequences(testing_sentences, word_index)
testing_padded = pad_sequences(testing_sequences, max_len=max_length)

word_freq = word_frequency(training_sentences, word_index)
print(word_freq)
# Out:
# {'new': 1318, 'trump': 1117, 'man': 1075, 'not': 634, 'just': 501, 'will': 484, 'one': 469, 'year': 440, 'report': 434, 'area': 421, 'donald': 407, 'day': 398, 'u': 398, 's': 392, 'can': 387, 'says': 385, 'woman': 378, 'first': 376, 'time': 365, 'like': 356, 'no': 352, 'get': 346, 'old': 332, 'trumps': 331, 'off': 326, 'now': 325, 'life': 319, 'obama': 317, 'people': 311, 'house': 290, 'women': 289, 'white': 281, 'back': 278, 'still': 276, 'make': 275, 'clinton': 264, '5': 260, 'world': 251, 'americans': 246, 'years': 240, 'way': 239, 'family': 231, 'black': 230, 'study': 225, 'gop': 218, 'best': 215, 'bill': 211, 'american': 208, 'school': 207, 'police': 206, 'watch': 206, '3': 205, 'show': 205, 'really': 200, 'president': 198, 'home': 196, 'last': 194, 'video': 194, 'finds': 194, 'death': 193, 'cant': 193, 'know': 193, '10': 192, 'things': 191, 'good': 191, 'going': 190, 'state': 189, 'hillary': 187, 'love': 184, 'nation': 177, 'may': 174, '2': 174, 'health': 172, 'say': 172, 'parents': 172, 'big': 171, 'every': 171, 'right': 169, 'work': 168, '000': 166, 'need': 166, 'dead': 165, 'kids': 164, 'take': 164, 'gets': 164, 'mom': 163, 'campaign': 162, 'party': 161, 'little': 155, 'getting': 155, 'high': 155, 'america': 154, 'news': 153, 'john': 152, 'court': 152, 'real': 151, 'self': 150, 'makes': 150, 'dont': 150, 'gay': 147, 'child': 146, 'takes': 146, 'election': 146, 'go': 145, 'never': 145, 'calls': 145, 'see': 144, '7': 143, 'doesnt': 143, 'change': 142, '4': 142, 'war': 142, 'want': 141, 'local': 141, 'star': 138, 'nations': 137, 'next': 136, 'guy': 136, '6': 135, 'college': 135, 'stop': 134, 'game': 134, 'bush': 132, 'look': 132, 'sex': 132, 'baby': 132, 'even': 132, 'around': 131, 'plan': 130, 'got': 129, 'office': 128, 'another': 128, '1': 127, 'dog': 127, 'thing': 126, 'ever': 126, 'gun': 125, 'million': 124, 'live': 124, 'two': 124, 'made': 124, 'actually': 123, 'job': 123, 'week': 122, 'wants': 120, 'dad': 120, 'us': 119, 'congress': 119, 'students': 119, 'help': 118, 'night': 118, 'care': 117, 'long': 117, 'mans': 117, 'north': 116, 'friends': 115, 'debate': 115, 'national': 114, 'season': 112, 'finally': 112, 'free': 112, 'couple': 112, 'much': 111, 'wont': 111, '20': 110, 'ways': 109, 'climate': 109, 'anti': 108, 'sexual': 108, 'give': 107, 'god': 107, 'city': 107, '9': 107, 'top': 106, 'without': 106, 'shows': 106, '8': 106, 'away': 105, 'story': 105, 'making': 105, 'history': 104, 'teen': 104, 'bad': 104, 'shooting': 103, 'men': 103, 'reveals': 103, 'trying': 102, 'children': 102, 'face': 102, 'money': 101, 'paul': 101, 'media': 101, 'end': 101, 'better': 100, 'senate': 100, 'food': 100, 'tv': 100, 'everyone': 99, 'law': 99, 'facebook': 98, 'tell': 98, 'entire': 97, 'movie': 97, 'supreme': 97, 'fight': 97, 'attack': 96, 'business': 96, 'announces': 96, 'girl': 95, 'found': 95, 'part': 95, 'republican': 95, 'government': 95, 'single': 94, 'film': 94, 'deal': 94, 'enough': 94, 'fire': 94, 'body': 93, 'son': 93, 'car': 93, 'think': 93, 'come': 92, 'york': 92, 'introduces': 92, 'wedding': 92, 'great': 92, 'pope': 91, 'talk': 91, 'former': 90, 'friend': 90, '11': 90, 'second': 90, 'book': 90, 'power': 89, 'find': 89, 'looking': 89, 'must': 88, 'james': 88, 'sanders': 88, 'pretty': 88, 'morning': 86, 'rights': 86, 'christmas': 86, 'thinks': 86, 'coming': 86, 'run': 86, 'middle': 86, 'call': 86, 'didnt': 85, 'used': 85, 'public': 85, 'future': 85, 'already': 85, 'speech': 85, 'republicans': 85, 'line': 84, 'marriage': 84, 'race': 84, 'support': 83, 'photos': 83, 'violence': 83, 'presidential': 82, 'keep': 82, 'democrats': 82, 'email': 81, 'name': 81, 'behind': 80, 'tax': 80, 'fans': 80, 'full': 80, 'vote': 80, '2016': 80, 'use': 80, 'girls': 80, 'worlds': 79, 'asks': 79, 'control': 79, '12': 79, 'security': 79, 'department': 79, 'secret': 78, 'company': 78, 'voters': 78, 'room': 78, 'open': 78, 'case': 77, 'team': 77, 'goes': 77, 'group': 77, 'win': 77, 'twitter': 77, 'poll': 77, 'times': 76, 'human': 76, 'missing': 7 ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim

class TextClassificationModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim=24, lstm_layers=1):
        super(TextClassificationModel, self).__init__()

        # Embedding layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

        # LSTM layer
        self.lstm = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=hidden_dim,
            num_layers=lstm_layers,
            batch_first=True
        )

        # Global pooling
        self.global_pool = nn.AdaptiveAvgPool1d(1)

        # Fully connected layers
        self.fc1 = nn.Linear(hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, 1)

        # Activation functions
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        # x shape: (batch_size, sequence_length)

        # Get embeddings
        embedded = self.embedding(x)  # Shape: (batch_size, sequence_length, embedding_dim)

        # Pass through LSTM
        lstm_out, _ = self.lstm(embedded)  # Shape: (batch_size, sequence_length, hidden_dim)

        # Transpose for global pooling (expecting: batch, channels, sequence_length)
        lstm_out = lstm_out.transpose(1, 2)  # Shape: (batch_size, hidden_dim, sequence_length)

        # Apply global pooling
        pooled = self.global_pool(lstm_out)  # Shape: (batch_size, hidden_dim, 1)
        pooled = pooled.squeeze(-1)  # Shape: (batch_size, hidden_dim)

        # Pass through fully connected layers
        x = self.relu(self.fc1(pooled))
        x = self.sigmoid(self.fc2(x))

        return x

# Assuming vocab_size and embedding_dim are defined
vocab_size = len(word_index)  # Example value

# Create the model
model = TextClassificationModel(vocab_size, embedding_dim)


# Define loss function and optimizer
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001, betas=(0.9, 0.999), amsgrad=False)

# Print model summary
print(model)
# Out:
# TextClassificationModel(
#   (embedding): Embedding(2000, 7)
#   (lstm): LSTM(7, 24, batch_first=True)
#   (global_pool): AdaptiveAvgPool1d(output_size=1)
#   (fc1): Linear(in_features=24, out_features=24, bias=True)
#   (fc2): Linear(in_features=24, out_features=1, bias=True)
#   (relu): ReLU()
#   (sigmoid): Sigmoid()
# )

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import numpy as np

# Assuming your TextClassificationModel is already defined

# Convert your preprocessed data to PyTorch tensors
training_padded = torch.tensor(training_padded, dtype=torch.long)
testing_padded = torch.tensor(testing_padded, dtype=torch.long)
training_labels = torch.tensor(training_labels, dtype=torch.float32)
testing_labels = torch.tensor(testing_labels, dtype=torch.float32)

# Create DataLoader objects
batch_size = 32
train_dataset = TensorDataset(training_padded, training_labels)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataset = TensorDataset(testing_padded, testing_labels)
test_loader = DataLoader(test_dataset, batch_size=batch_size)


# Training loop
num_epochs = 300
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
train_loss_history = []
train_acc_history = []
val_loss_history = []
val_acc_history = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    train_correct = 0
    train_total = 0

    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs.squeeze(), targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_total += targets.size(0)
        train_correct += ((outputs.squeeze() > 0.5) == targets).sum().item()

    # Validation
    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs.squeeze(), targets)

            val_loss += loss.item()
            val_total += targets.size(0)
            val_correct += ((outputs.squeeze() > 0.5) == targets).sum().item()

    print(f'Epoch {epoch+1}/{num_epochs}:')
    train_loss_history.append(train_loss/len(train_loader))
    train_acc_history.append(train_correct/train_total)
    val_loss_history.append(val_loss/len(test_loader))
    val_acc_history.append(val_correct/val_total)
    print(f'Train Loss: {train_loss/len(train_loader):.4f}, Train Acc: {train_correct/train_total:.4f}')
    print(f'Val Loss: {val_loss/len(test_loader):.4f}, Val Acc: {val_correct/val_total:.4f}')

# After training, you can save the model
torch.save(model.state_dict(), 'text_classification_model.pth')
# Out:
# <ipython-input-76-d0f302aa1699>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   training_padded = torch.tensor(training_padded, dtype=torch.long)
# <ipython-input-76-d0f302aa1699>:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testing_padded = torch.tensor(testing_padded, dtype=torch.long)
# <ipython-input-76-d0f302aa1699>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   training_labels = torch.tensor(training_labels, dtype=torch.float32)
# <ipython-input-76-d0f302aa1699>:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   testing_labels = torch.tensor(testing_labels, dtype=torch.float32)
# Epoch 1/300:
# Train Loss: 0.6908, Train Acc: 0.5257
# Val Loss: 0.6839, Val Acc: 0.5700
# Epoch 2/300:
# Train Loss: 0.6857, Train Acc: 0.5596
# Val Loss: 0.6830, Val Acc: 0.5700
# Epoch 3/300:
# Train Loss: 0.6856, Train Acc: 0.5596
# Val Loss: 0.6829, Val Acc: 0.5700
# Epoch 4/300:
# Train Loss: 0.6856, Train Acc: 0.5596
# Val Loss: 0.6828, Val Acc: 0.5700
# Epoch 5/300:
# Train Loss: 0.6855, Train Acc: 0.5596
# Val Loss: 0.6828, Val Acc: 0.5700
# Epoch 6/300:
# Train Loss: 0.6854, Train Acc: 0.5596
# Val Loss: 0.6827, Val Acc: 0.5700
# Epoch 7/300:
# Train Loss: 0.6853, Train Acc: 0.5596
# Val Loss: 0.6826, Val Acc: 0.5700
# Epoch 8/300:
# Train Loss: 0.6852, Train Acc: 0.5596
# Val Loss: 0.6825, Val Acc: 0.5700
# Epoch 9/300:
# Train Loss: 0.6850, Train Acc: 0.5596
# Val Loss: 0.6826, Val Acc: 0.5700
# Epoch 10/300:
# Train Loss: 0.6849, Train Acc: 0.5596
# Val Loss: 0.6823, Val Acc: 0.5700
# Epoch 11/300:
# Train Loss: 0.6848, Train Acc: 0.5596
# Val Loss: 0.6817, Val Acc: 0.5700
# Epoch 12/300:
# Train Loss: 0.6844, Train Acc: 0.5596
# Val Loss: 0.6813, Val Acc: 0.5700
# Epoch 13/300:
# Train Loss: 0.6836, Train Acc: 0.5597
# Val Loss: 0.6802, Val Acc: 0.5700
# Epoch 14/300:
# Train Loss: 0.6824, Train Acc: 0.5597
# Val Loss: 0.6778, Val Acc: 0.5697
# Epoch 15/300:
# Train Loss: 0.6780, Train Acc: 0.5649
# Val Loss: 0.6704, Val Acc: 0.5902
# Epoch 16/300:
# Train Loss: 0.6729, Train Acc: 0.5781
# Val Loss: 0.6668, Val Acc: 0.5843
# Epoch 17/300:
# Train Loss: 0.6714, Train Acc: 0.5792
# Val Loss: 0.6652, Val Acc: 0.5956
# Epoch 18/300:
# Train Loss: 0.6699, Train Acc: 0.5845
# Val Loss: 0.6637, Val Acc: 0.5958
# Epoch 19/300:
# Train Loss: 0.6684, Train Acc: 0.5877
# Val Loss: 0.6626, Val Acc: 0.5942
# Epoch 20/300:
# Train Loss: 0.6683, Train Acc: 0.5818
# Val Loss: 0.6623, Val Acc: 0.5994
# Epoch 21/300:
# Train Loss: 0.6675, Train Acc: 0.5889
# Val Loss: 0.6611, Val Acc: 0.5926
# Epoch 22/300:
# Train Loss: 0.6678, Train Acc: 0.5847
# Val Loss: 0.6615, Val Acc: 0.5983
# Epoch 23/300:
# Train Loss: 0.6660, Train Acc: 0.5906
# Val Loss: 0.6599, Val Acc: 0.5994
# Epoch 24/300:
# Train Loss: 0.6657, Train Acc: 0.5873
# Val Loss: 0.6591, Val Acc: 0.5967
# Epoch 25/300:
# Train Loss: 0.6640, Train Acc: 0.5907
# Val Loss: 0.6592, Val Acc: 0.5961
# Epoch 26/300:
# Train Loss: 0.6640, Train Acc: 0.5913
# Val Loss: 0.6580, Val Acc: 0.5994
# Epoch 27/300:
# Train Loss: 0.6626, Train Acc: 0.5974
# Val Loss: 0.6585, Val Acc: 0.5985
# Epoch 28/300:
# Train Loss: 0.6621, Train Acc: 0.5946
# Val Loss: 0.6557, Val Acc: 0.6034
# Epoch 29/300:
# Train Loss: 0.6617, Train Acc: 0.5938
# Val Loss: 0.6550, Val Acc: 0.6031
# Epoch 30/300:
# Train Loss: 0.6603, Train Acc: 0.5959
# Val Loss: 0.6575, Val Acc: 0.5972
# Epoch 31/300:
# Train Loss: 0.6586, Train Acc: 0.5966
# Val Loss: 0.6539, Val Acc: 0.6029
# Epoch 32/300:
# Train Loss: 0.6590, Train Acc: 0.5982
# Val Loss: 0.6526, Val Acc: 0.6029
# Epoch 33/300:
# Train Loss: 0.6585, Train Acc: 0.5973
# Val Loss: 0.6530, Val Acc: 0.6056
# Epoch 34/300:
# Train Loss: 0.6577, Train Acc: 0.5963
# Val Loss: 0.6513, Val Acc: 0.6066
# Epoch 35/300:
# Train Loss: 0.6575, Train Acc: 0.6006
# Val Loss: 0.6510, Val Acc: 0.6096
# Epoch 36/300:
# Train Loss: 0.6564, Train Acc: 0.6025
# Val Loss: 0.6497, Val Acc: 0.6056
# Epoch 37/300:
# Train Loss: 0.6556, Train Acc: 0.6025
# Val Loss: 0.6493, Val Acc: 0.6120
# Epoch 38/300:
# Train Loss: 0.6551, Train Acc: 0.6066
# Val Loss: 0.6488, Val Acc: 0.6118
# Epoch 39/300:
# Train Loss: 0.6537, Train Acc: 0.6055
# Val Loss: 0.6492, Val Acc: 0.6061
# Epoch 40/300:
# Train Loss: 0.6529, Train Acc: 0.6062
# Val Loss: 0.6500, Val Acc: 0.6042
# Epoch 41/300:
# Train Loss: 0.6527, Train Acc: 0.6092
# Val Loss: 0.6488, Val Acc: 0.6083
# Epoch 42/300:
# Train Loss: 0.6510, Train Acc: 0.6119
# Val Loss: 0.6484, Val Acc: 0.6080
# Epoch 43/300:
# Train Loss: 0.6507, Train Acc: 0.6115
# Val Loss: 0.6455, Val Acc: 0.6145
# Epoch 44/300:
# Train Loss: 0.6504, Train Acc: 0.6103
# Val Loss: 0.6436, Val Acc: 0.6109
# Epoch 45/300:
# Train Loss: 0.6495, Train Acc: 0.6119
# Val Loss: 0.6432, Val Acc: 0.6174
# Epoch 46/300:
# Train Loss: 0.6497, Train Acc: 0.6110
# Val Loss: 0.6454, Val Acc: 0.6158
# Epoch 47/300:
# Train Loss: 0.6468, Train Acc: 0.6152
# Val Loss: 0.6419, Val Acc: 0.6198
# Epoch 48/300:
# Train Loss: 0.6465, Train Acc: 0.6135
# Val Loss: 0.6404, Val Acc: 0.6204
# Epoch 49/300:
# Train Loss: 0.6464, Train Acc: 0.6177
# Val Loss: 0.6410, Val Acc: 0.6209
# Epoch 50/300:
# Train Loss: 0.6438, Train Acc: 0.6179
# Val Loss: 0.6410, Val Acc: 0.6215
# Epoch 51/300:
# Train Loss: 0.6436, Train Acc: 0.6192
# Val Loss: 0.6384, Val Acc: 0.6242
# Epoch 52/300:
# Train Loss: 0.6426, Train Acc: 0.6233
# Val Loss: 0.6378, Val Acc: 0.6266
# Epoch 53/300:
# Train Loss: 0.6426, Train Acc: 0.6209
# Val Loss: 0.6377, Val Acc: 0.6274
# Epoch 54/300:
# Train Loss: 0.6397, Train Acc: 0.6254
# Epoch 79/300:
# Train Loss: 0.6101, Train Acc: 0.6566
# Val Loss: 0.6037, Val Acc: 0.6562
# Epoch 80/300:
# Train Loss: 0.6092, Train Acc: 0.6589
# Val Loss: 0.6032, Val Acc: 0.6581
# Epoch 81/300:
# Train Loss: 0.6081, Train Acc: 0.6581
# Val Loss: 0.6049, Val Acc: 0.6579
# Epoch 82/300:
# Train Loss: 0.6079, Train Acc: 0.6596
# Val Loss: 0.6010, Val Acc: 0.6579
# Epoch 83/300:
# Train Loss: 0.6074, Train Acc: 0.6631
# Val Loss: 0.6011, Val Acc: 0.6611
# Epoch 84/300:
# Train Loss: 0.6037, Train Acc: 0.6642
# Val Loss: 0.5995, Val Acc: 0.6614
# Epoch 85/300:
# Train Loss: 0.6031, Train Acc: 0.6644
# Val Loss: 0.5992, Val Acc: 0.6630
# Epoch 86/300:
# Train Loss: 0.6035, Train Acc: 0.6658
# Val Loss: 0.6032, Val Acc: 0.6627
# Epoch 87/300:
# Train Loss: 0.6014, Train Acc: 0.6665
# Val Loss: 0.5967, Val Acc: 0.6654
# Epoch 88/300:
# Train Loss: 0.6021, Train Acc: 0.6643
# Val Loss: 0.5975, Val Acc: 0.6678
# Epoch 89/300:
# Train Loss: 0.6005, Train Acc: 0.6656
# Val Loss: 0.5930, Val Acc: 0.6649
# Epoch 90/300:
# Train Loss: 0.5997, Train Acc: 0.6705
# Val Loss: 0.5937, Val Acc: 0.6684
# Epoch 91/300:
# Train Loss: 0.5999, Train Acc: 0.6672
# Val Loss: 0.5922, Val Acc: 0.6719
# Epoch 92/300:
# Train Loss: 0.5961, Train Acc: 0.6727
# Val Loss: 0.5942, Val Acc: 0.6730
# Epoch 93/300:
# Train Loss: 0.5962, Train Acc: 0.6713
# Val Loss: 0.5896, Val Acc: 0.6695
# Epoch 94/300:
# Train Loss: 0.5950, Train Acc: 0.6718
# Val Loss: 0.5893, Val Acc: 0.6754
# Epoch 95/300:
# Train Loss: 0.5945, Train Acc: 0.6758
# Val Loss: 0.5906, Val Acc: 0.6746
# Epoch 96/300:
# Train Loss: 0.5908, Train Acc: 0.6756
# Val Loss: 0.5901, Val Acc: 0.6746
# Epoch 97/300:
# Train Loss: 0.5934, Train Acc: 0.6720
# Val Loss: 0.5878, Val Acc: 0.6767
# Epoch 98/300:
# Train Loss: 0.5919, Train Acc: 0.6745
# Val Loss: 0.5902, Val Acc: 0.6740
# Epoch 99/300:
# Train Loss: 0.5891, Train Acc: 0.6793
# Val Loss: 0.5872, Val Acc: 0.6759
# Epoch 100/300:
# Train Loss: 0.5911, Train Acc: 0.6760
# Val Loss: 0.5819, Val Acc: 0.6740
# Epoch 101/300:
# Train Loss: 0.5886, Train Acc: 0.6792
# Val Loss: 0.5807, Val Acc: 0.6727
# Epoch 102/300:
# Train Loss: 0.5869, Train Acc: 0.6795
# Val Loss: 0.5804, Val Acc: 0.6808
# Epoch 103/300:
# Train Loss: 0.5866, Train Acc: 0.6800
# Val Loss: 0.5483, Val Acc: 0.7080
# Epoch 153/300:
# Train Loss: 0.5454, Train Acc: 0.7123
# Val Loss: 0.5442, Val Acc: 0.7099
# Epoch 154/300:
# Train Loss: 0.5461, Train Acc: 0.7129
# Val Loss: 0.5457, Val Acc: 0.7131
# Epoch 155/300:
# Train Loss: 0.5440, Train Acc: 0.7162
# Val Loss: 0.5438, Val Acc: 0.7118
# Epoch 156/300:
# Train Loss: 0.5449, Train Acc: 0.7169
# Val Loss: 0.5489, Val Acc: 0.7104
# Epoch 157/300:
# Train Loss: 0.5437, Train Acc: 0.7166
# Val Loss: 0.5467, Val Acc: 0.7121
# Epoch 158/300:
# Train Loss: 0.5436, Train Acc: 0.7127
# Val Loss: 0.5421, Val Acc: 0.7115
# Epoch 159/300:
# Train Loss: 0.5429, Train Acc: 0.7186
# Val Loss: 0.5398, Val Acc: 0.7150
# Epoch 160/300:
# Train Loss: 0.5410, Train Acc: 0.7191
# Val Loss: 0.5396, Val Acc: 0.7145
# Epoch 161/300:
# Train Loss: 0.5401, Train Acc: 0.7177
# Val Loss: 0.5406, Val Acc: 0.7137
# Epoch 162/300:
# Train Loss: 0.5397, Train Acc: 0.7163
# Val Loss: 0.5400, Val Acc: 0.7129
# Epoch 163/300:
# Train Loss: 0.5363, Train Acc: 0.7210
# Val Loss: 0.5470, Val Acc: 0.7139
# Epoch 164/300:
# Train Loss: 0.5372, Train Acc: 0.7190
# Val Loss: 0.5423, Val Acc: 0.7147
# Epoch 165/300:
# Train Loss: 0.5369, Train Acc: 0.7206
# Val Loss: 0.5418, Val Acc: 0.7129
# Epoch 166/300:
# Train Loss: 0.5382, Train Acc: 0.7193
# Val Loss: 0.5399, Val Acc: 0.7139
# Epoch 167/300:
# Train Loss: 0.5351, Train Acc: 0.7209
# Val Loss: 0.5432, Val Acc: 0.7131
# Epoch 168/300:
# Train Loss: 0.5352, Train Acc: 0.7219
# Val Loss: 0.5409, Val Acc: 0.7191
# Epoch 169/300:
# Train Loss: 0.5361, Train Acc: 0.7181
# Val Loss: 0.5368, Val Acc: 0.7172
# Epoch 170/300:
# Train Loss: 0.5321, Train Acc: 0.7266
# Val Loss: 0.5401, Val Acc: 0.7191
# Epoch 171/300:
# Train Loss: 0.5318, Train Acc: 0.7249
# Val Loss: 0.5357, Val Acc: 0.7158
# Epoch 172/300:
# Train Loss: 0.5326, Train Acc: 0.7222
# Val Loss: 0.5341, Val Acc: 0.7183
# Epoch 173/300:
# Train Loss: 0.5333, Train Acc: 0.7198
# Val Loss: 0.5367, Val Acc: 0.7193
# Epoch 174/300:
# Train Loss: 0.5301, Train Acc: 0.7245
# Val Loss: 0.5328, Val Acc: 0.7172
# Epoch 175/300:
# Train Loss: 0.5293, Train Acc: 0.7252
# Val Loss: 0.5340, Val Acc: 0.7196
# Epoch 176/300:
# Train Loss: 0.5317, Train Acc: 0.7221
# Val Loss: 0.5322, Val Acc: 0.7193
# Epoch 177/300:
# Train Loss: 0.5297, Train Acc: 0.7257
# Val Loss: 0.5342, Val Acc: 0.7218
# Epoch 178/300:
# Train Loss: 0.5280, Train Acc: 0.7288
# Val Loss: 0.5338, Val Acc: 0.7236
# Epoch 179/300:
# Train Loss: 0.5284, Train Acc: 0.7250
# Val Loss: 0.5338, Val Acc: 0.7218
# Epoch 180/300:
# Train Loss: 0.5293, Train Acc: 0.7279
# Val Loss: 0.5348, Val Acc: 0.7242
# Epoch 181/300:
# Train Loss: 0.5265, Train Acc: 0.7271
# Val Loss: 0.5308, Val Acc: 0.7220
# Epoch 182/300:
# Train Loss: 0.5292, Train Acc: 0.7263
# Val Loss: 0.5324, Val Acc: 0.7220
# Epoch 183/300:
# Train Loss: 0.5261, Train Acc: 0.7263
# Val Loss: 0.5292, Val Acc: 0.7207
# Epoch 184/300:
# Train Loss: 0.5272, Train Acc: 0.7263
# Val Loss: 0.5358, Val Acc: 0.7220
# Epoch 185/300:
# Train Loss: 0.5266, Train Acc: 0.7274
# Val Loss: 0.5289, Val Acc: 0.7250
# Epoch 186/300:
# Train Loss: 0.5229, Train Acc: 0.7294
# Val Loss: 0.5259, Val Acc: 0.7247
# Epoch 187/300:
# Train Loss: 0.5229, Train Acc: 0.7292
# Val Loss: 0.5261, Val Acc: 0.7250
# Epoch 188/300:
# Train Loss: 0.5203, Train Acc: 0.7326
# Val Loss: 0.5384, Val Acc: 0.7199
# Epoch 189/300:
# Train Loss: 0.5193, Train Acc: 0.7330
# Val Loss: 0.5287, Val Acc: 0.7263
# Epoch 190/300:
# Train Loss: 0.5220, Train Acc: 0.7310
# Val Loss: 0.5257, Val Acc: 0.7269
# Epoch 191/300:
# Train Loss: 0.5222, Train Acc: 0.7302
# Val Loss: 0.5303, Val Acc: 0.7263
# Epoch 192/300:
# Train Loss: 0.5191, Train Acc: 0.7341
# Val Loss: 0.5313, Val Acc: 0.7236
# Epoch 193/300:
# Train Loss: 0.5202, Train Acc: 0.7301
# Val Loss: 0.5233, Val Acc: 0.7277
# Epoch 194/300:
# Train Loss: 0.5190, Train Acc: 0.7349
# Val Loss: 0.5245, Val Acc: 0.7263
# Epoch 195/300:
# Train Loss: 0.5185, Train Acc: 0.7343
# Val Loss: 0.5246, Val Acc: 0.7269
# Epoch 196/300:
# Train Loss: 0.5177, Train Acc: 0.7353
# Val Loss: 0.5299, Val Acc: 0.7272
# Epoch 197/300:
# Train Loss: 0.5181, Train Acc: 0.7313
# Val Loss: 0.5302, Val Acc: 0.7277
# Epoch 198/300:
# Train Loss: 0.5183, Train Acc: 0.7339
# Val Loss: 0.5236, Val Acc: 0.7285
# Epoch 199/300:
# Train Loss: 0.5168, Train Acc: 0.7360
# Val Loss: 0.5263, Val Acc: 0.7266
# Epoch 200/300:
# Train Loss: 0.5140, Train Acc: 0.7353
# Val Loss: 0.5213, Val Acc: 0.7296
# Epoch 201/300:
# Train Loss: 0.5170, Train Acc: 0.7330
# Val Loss: 0.5254, Val Acc: 0.7304
# Epoch 202/300:
# Train Loss: 0.5123, Train Acc: 0.7407
# Val Loss: 0.5206, Val Acc: 0.7301
# Epoch 203/300:
# Train Loss: 0.5155, Train Acc: 0.7343
# Val Loss: 0.5235, Val Acc: 0.7290
# Epoch 204/300:
# Train Loss: 0.5142, Train Acc: 0.7367
# Val Loss: 0.5289, Val Acc: 0.7266
# Epoch 205/300:
# Train Loss: 0.5118, Train Acc: 0.7385
# Val Loss: 0.5240, Val Acc: 0.7298
# Epoch 206/300:
# Train Loss: 0.5118, Train Acc: 0.7376
# Val Loss: 0.5201, Val Acc: 0.7315
# Epoch 207/300:
# Train Loss: 0.5123, Train Acc: 0.7375
# Val Loss: 0.5333, Val Acc: 0.7207
# Epoch 208/300:
# Train Loss: 0.5110, Train Acc: 0.7382
# Val Loss: 0.5222, Val Acc: 0.7317
# Epoch 209/300:
# Train Loss: 0.5139, Train Acc: 0.7411
# Val Loss: 0.5219, Val Acc: 0.7288
# Epoch 210/300:
# Train Loss: 0.5102, Train Acc: 0.7412
# Val Loss: 0.5214, Val Acc: 0.7301
# Epoch 211/300:
# Train Loss: 0.5088, Train Acc: 0.7409
# Val Loss: 0.5191, Val Acc: 0.7315
# Epoch 212/300:
# Train Loss: 0.5088, Train Acc: 0.7397
# Val Loss: 0.5166, Val Acc: 0.7350
# Epoch 213/300:
# Train Loss: 0.5094, Train Acc: 0.7367
# Val Loss: 0.5205, Val Acc: 0.7320
# Epoch 214/300:
# Train Loss: 0.5070, Train Acc: 0.7407
# Val Loss: 0.5236, Val Acc: 0.7280
# Epoch 215/300:
# Train Loss: 0.5106, Train Acc: 0.7394
# Val Loss: 0.5174, Val Acc: 0.7344
# Epoch 216/300:
# Train Loss: 0.5058, Train Acc: 0.7442
# Val Loss: 0.5185, Val Acc: 0.7296
# Epoch 217/300:
# Train Loss: 0.5034, Train Acc: 0.7430
# Val Loss: 0.5168, Val Acc: 0.7355
# Epoch 218/300:
# Train Loss: 0.5096, Train Acc: 0.7376
# Val Loss: 0.5147, Val Acc: 0.7355
# Epoch 219/300:
# Train Loss: 0.5055, Train Acc: 0.7424
# Val Loss: 0.5168, Val Acc: 0.7336
# Epoch 220/300:
# Train Loss: 0.5045, Train Acc: 0.7418
# Val Loss: 0.5179, Val Acc: 0.7350
# Epoch 221/300:
# Train Loss: 0.5028, Train Acc: 0.7434
# Val Loss: 0.5123, Val Acc: 0.7360
# Epoch 222/300:
# Train Loss: 0.5048, Train Acc: 0.7399
# Val Loss: 0.5170, Val Acc: 0.7317
# Epoch 223/300:
# Train Loss: 0.5042, Train Acc: 0.7447
# Val Loss: 0.5233, Val Acc: 0.7296
# Epoch 224/300:
# Train Loss: 0.5035, Train Acc: 0.7420
# Val Loss: 0.5186, Val Acc: 0.7296
# Epoch 225/300:
# Train Loss: 0.5040, Train Acc: 0.7429
# Val Loss: 0.5178, Val Acc: 0.7315
# Epoch 226/300:
# Train Loss: 0.4845, Train Acc: 0.7578
# Val Loss: 0.5031, Val Acc: 0.7385
# Epoch 276/300:
# Train Loss: 0.4813, Train Acc: 0.7601
# Val Loss: 0.5045, Val Acc: 0.7385
# Epoch 277/300:
# Train Loss: 0.4792, Train Acc: 0.7588
# Val Loss: 0.4993, Val Acc: 0.7409
# Epoch 278/300:
# Train Loss: 0.4794, Train Acc: 0.7602
# Val Loss: 0.4968, Val Acc: 0.7468
# Epoch 279/300:
# Train Loss: 0.4774, Train Acc: 0.7634
# Val Loss: 0.4951, Val Acc: 0.7460
# Epoch 280/300:
# Train Loss: 0.4787, Train Acc: 0.7601
# Val Loss: 0.4967, Val Acc: 0.7447
# Epoch 281/300:
# Train Loss: 0.4774, Train Acc: 0.7608
# Val Loss: 0.4959, Val Acc: 0.7471
# Epoch 282/300:
# Train Loss: 0.4779, Train Acc: 0.7635
# Val Loss: 0.4994, Val Acc: 0.7398
# Epoch 283/300:
# Train Loss: 0.4776, Train Acc: 0.7629
# Val Loss: 0.5013, Val Acc: 0.7409
# Epoch 284/300:
# Train Loss: 0.4768, Train Acc: 0.7663
# Val Loss: 0.4994, Val Acc: 0.7431
# Epoch 285/300:
# Train Loss: 0.4757, Train Acc: 0.7624
# Val Loss: 0.4997, Val Acc: 0.7401
# Epoch 286/300:
# Train Loss: 0.4747, Train Acc: 0.7647
# Val Loss: 0.4980, Val Acc: 0.7417
# Epoch 287/300:
# Train Loss: 0.4778, Train Acc: 0.7629
# Val Loss: 0.4951, Val Acc: 0.7458
# Epoch 288/300:
# Train Loss: 0.4757, Train Acc: 0.7630
# Val Loss: 0.4957, Val Acc: 0.7449
# Epoch 289/300:
# Train Loss: 0.4771, Train Acc: 0.7614
# Val Loss: 0.5012, Val Acc: 0.7409
# Epoch 290/300:
# Train Loss: 0.4744, Train Acc: 0.7612
# Val Loss: 0.4928, Val Acc: 0.7487
# Epoch 291/300:
# Train Loss: 0.4752, Train Acc: 0.7627
# Val Loss: 0.4911, Val Acc: 0.7493
# Epoch 292/300:
# Train Loss: 0.4728, Train Acc: 0.7652
# Val Loss: 0.4930, Val Acc: 0.7468
# Epoch 293/300:
# Train Loss: 0.4755, Train Acc: 0.7633
# Val Loss: 0.4939, Val Acc: 0.7458
# Epoch 294/300:
# Train Loss: 0.4723, Train Acc: 0.7640
# Val Loss: 0.4941, Val Acc: 0.7452
# Epoch 295/300:
# Train Loss: 0.4707, Train Acc: 0.7659
# Val Loss: 0.4996, Val Acc: 0.7406
# Epoch 296/300:
# Train Loss: 0.4728, Train Acc: 0.7650
# Val Loss: 0.4947, Val Acc: 0.7441
# Epoch 297/300:
# Train Loss: 0.4722, Train Acc: 0.7618
# Val Loss: 0.4920, Val Acc: 0.7466
# Epoch 298/300:
# Train Loss: 0.4697, Train Acc: 0.7668
# Val Loss: 0.4952, Val Acc: 0.7431
# Epoch 299/300:
# Train Loss: 0.4693, Train Acc: 0.7664
# Val Loss: 0.4900, Val Acc: 0.7501
# Epoch 300/300:
# Train Loss: 0.4720, Train Acc: 0.7650
# Val Loss: 0.4967, Val Acc: 0.7409

# %%
# !pip install torchinfo
from torchinfo import summary
summary(model,
        input_size=(batch_size, max_length),
        dtypes=[torch.long],  # Specify long dtype for embedding layer
        device='cpu')
# Out:
# Collecting torchinfo
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.8.0
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TextClassificationModel                  [32, 1]                   --
# ├─Embedding: 1-1                         [32, 85, 7]               14,000
# ├─AdaptiveAvgPool1d: 1-2                 [32, 7, 1]                --
# ├─Linear: 1-3                            [32, 8]                   64
# ├─ReLU: 1-4                              [32, 8]                   --
# ├─Dropout: 1-5                           [32, 8]                   --
# ├─Linear: 1-6                            [32, 1]                   9
# ├─Sigmoid: 1-7                           [32, 1]                   --
# ==========================================================================================
# Total params: 14,073
# Trainable params: 14,073
# Non-trainable params: 0
# Total mult-adds (M): 0.45
# ==========================================================================================
# Input size (MB): 0.02
# Forward/backward pass size (MB): 0.15
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.23
# ==========================================================================================

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_training_metrics(train_loss, train_acc, val_loss, val_acc):
    """
    Plot training and validation metrics on two subplots.

    Args:
        train_loss: Array of training loss values
        train_acc: Array of training accuracy values
        val_loss: Array of validation loss values
        val_acc: Array of validation accuracy values
    """
    # Create figure with two subplots side by side
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Plot epochs on x-axis
    epochs = range(1, len(train_loss) + 1)

    # First subplot: Loss
    ax1.plot(epochs, train_loss, 'b-', label='Training Loss')
    ax1.plot(epochs, val_loss, 'r-', label='Validation Loss')
    ax1.set_title('Training and Validation Loss')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.grid(True)

    # Second subplot: Accuracy
    ax2.plot(epochs, train_acc, 'b-', label='Training Accuracy')
    ax2.plot(epochs, val_acc, 'r-', label='Validation Accuracy')
    ax2.set_title('Training and Validation Accuracy')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Accuracy')
    ax2.legend()
    ax2.grid(True)

    # Add accuracy percentage labels
    ax2.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))

    # Adjust layout to prevent overlap
    plt.tight_layout()

    return fig

# Usage example:
plot_training_metrics(train_loss_history, train_acc_history, val_loss_history, val_acc_history)
plt.show()

# %%
print(word_index)
print(texts_to_sequences(test_sentences, word_index))
# Out:
# {'new': 2, 'trump': 3, 'man': 4, 'not': 5, 'just': 6, 'will': 7, 'one': 8, 'year': 9, 'report': 10, 'area': 11, 'donald': 12, 'day': 13, 'u': 14, 's': 15, 'can': 16, 'says': 17, 'woman': 18, 'first': 19, 'time': 20, 'like': 21, 'no': 22, 'get': 23, 'old': 24, 'trumps': 25, 'off': 26, 'now': 27, 'life': 28, 'obama': 29, 'people': 30, 'house': 31, 'women': 32, 'white': 33, 'back': 34, 'still': 35, 'make': 36, 'clinton': 37, '5': 38, 'world': 39, 'americans': 40, 'years': 41, 'way': 42, 'family': 43, 'black': 44, 'study': 45, 'gop': 46, 'best': 47, 'bill': 48, 'american': 49, 'school': 50, 'police': 51, 'watch': 52, '3': 53, 'show': 54, 'really': 55, 'president': 56, 'home': 57, 'last': 58, 'video': 59, 'finds': 60, 'death': 61, 'cant': 62, 'know': 63, '10': 64, 'things': 65, 'good': 66, 'going': 67, 'state': 68, 'hillary': 69, 'love': 70, 'nation': 71, 'may': 72, '2': 73, 'health': 74, 'say': 75, 'parents': 76, 'big': 77, 'every': 78, 'right': 79, 'work': 80, '000': 81, 'need': 82, 'dead': 83, 'kids': 84, 'take': 85, 'gets': 86, 'mom': 87, 'campaign': 88, 'party': 89, 'little': 90, 'getting': 91,
# [[1, 803, 753, 1, 1, 312, 97], [123, 1183, 160, 1, 1, 1543, 152], [1, 235, 7, 47, 1]]

# %%
def predict_sentences(model, sentences, vocab, max_len, device='cuda', threshold=0.5):
    """
    Make predictions for new sentences and interpret results
    """
    # Preprocess
    sequences = texts_to_sequences(sentences, vocab)
    padded = pad_sequences(sequences, max_len)
    #print(padded)

    # Convert to tensor
    input_ids = torch.tensor(padded, dtype=torch.long).to(device)

    # Get predictions
    model.eval()
    with torch.no_grad():
        outputs = model(input_ids)
        print(outputs)
        probabilities = outputs.squeeze().cpu().numpy()
        predictions = (probabilities >= threshold).astype(int)

    # Print results
    for sentence, prob, pred in zip(sentences, probabilities, predictions):
        print(f"\nText: {sentence}")
        print(f"Probability: {prob:.4f}")
        print(f"Classification: {'Sarcastic' if pred == 1 else 'Not Sarcastic'}")
        print(f"Confidence: {max(prob, 1-prob):.4f}")
        print("-" * 80)

test_sentences = ["granny starting to fear spiders in the garden might be real",
             "game of thrones season finale showing this sunday night",
             "PyTorch book will be a best seller"]

# Example usage:
model = model.to(device)
predict_sentences(
    model=model,
    sentences=test_sentences,
    vocab=word_index,
    max_len=85,
    threshold=0.5  # Adjust this threshold if needed
)
# Out:
# tensor([[0.5516],
#         [0.0765],
#         [0.0987]], device='cuda:0')
#
# Text: granny starting to fear spiders in the garden might be real
# Probability: 0.5516
# Classification: Sarcastic
# Confidence: 0.5516
# --------------------------------------------------------------------------------
#
# Text: game of thrones season finale showing this sunday night
# Probability: 0.0765
# Classification: Not Sarcastic
# Confidence: 0.9235
# --------------------------------------------------------------------------------
#
# Text: PyTorch book will be a best seller
# Probability: 0.0987
# Classification: Not Sarcastic
# Confidence: 0.9013
# --------------------------------------------------------------------------------

# %%
reverse_word_index = dict([(value, key)
for (key, value) in word_index.items()])

# %%
# Get the embedding weights as a numpy array
embedding_weights = model.embedding.weight.data.cpu().numpy()
print(embedding_weights.shape)

# If you want to see the embedding for a specific word:
def get_word_embedding(word, vocab, model):
    if word in vocab:
        word_idx = vocab[word]
        return model.embedding.weight.data[word_idx].cpu().numpy()
    else:
        return None

# Example usage:
word = "game"
embedding = get_word_embedding(word, word_index, model)
if embedding is not None:
    print(f"Embedding for '{word}': {embedding}")
    print(f"Embedding dimension: {len(embedding)}")
else:
    print(f"Word '{word}' not found in vocabulary")

# If you want to save all embeddings with their corresponding words:
word_embeddings = {}
for word, idx in word_index.items():
    word_embeddings[word] = model.embedding.weight.data[idx].cpu().numpy()
# Out:
# (2000, 7)
# Embedding for 'game': [ 0.76860815  0.15977526  0.5715948   0.1268394  -0.59308386 -1.1009454
#  -1.0531788 ]
# Embedding dimension: 7

# %%
print(reverse_word_index[2])
print(embedding_weights[2])
# Out:
# new
# [-0.27116913 -1.3026129   1.6390767   0.4922502  -0.6025921   1.4584142
#   0.05054485]

# %%
import io

out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
  word = reverse_word_index[word_num]
  embeddings = embedding_weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %%
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')
